# %% [markdown]
# <a href="https://colab.research.google.com/github/samrudhi-shirode/AI-Projects/blob/main/Credit_Card_Default_Model_Production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Credit Card Default Model Prediction using Artificial Neural Network - ANN
# ### Build a model that will predict borrower's chance of defaulting on credit loans.

# %% [markdown]
# Change the runtime and Connect to GPU before executing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Data Gathering is done from UCI website. For that install ucimlrepo first.

# %%
pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.12/dist-packages (from ucimlrepo) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
default_of_credit_card_clients = fetch_ucirepo(id=350)

# data (as pandas dataframes)
X = default_of_credit_card_clients.data.features
y = default_of_credit_card_clients.data.targets

X.head()
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X14    X15    X16  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...    689      0      0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...   2682   3272   3455
# 2   90000   2   2   2  34   0   0   0   0    0  ...  13559  14331  14948
# 3   50000   2   2   1  37   0   0   0   0    0  ...  49291  28314  28959
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...  35835  20940  19146
#
#      X17   X18    X19    X20   X21   X22   X23
# 0      0     0    689      0     0     0     0
# 1   3261     0   1000   1000  1000     0  2000
# 2  15549  1518   1500   1000  1000  1000  5000
# 3  29547  2000   2019   1200  1100  1069  1000
# 4  19131  2000  36681  10000  9000   689   679
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
#    Y
# 0  1
# 1  1
# 2  0
# 3  0
# 4  0

# %%
new_cols = ['Credit_Amount','Gender','Education','Marital status','Age','Repay_Sept','Repay_Aug','Repay_July','Repay_June','Repay_May','Repay_April',
            'Bill_Sept','Bill_Aug','Bill_July','Bill__June','Bill_May','Bill_April',
           'Amount_paid_Sept','Amount_paid_Aug','Amount_paid_July','Amount_paid_June','Amount_paid_May','Amount_paid_April']

# %%
X.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10', 'X11',
#        'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19', 'X20', 'X21',
#        'X22', 'X23'],
#       dtype='object')

# %%
X.columns = new_cols
X.columns
# Out:
# Index(['Credit_Amount', 'Gender', 'Education', 'Marital status', 'Age',
#        'Repay_Sept', 'Repay_Aug', 'Repay_July', 'Repay_June', 'Repay_May',
#        'Repay_April', 'Bill_Sept', 'Bill_Aug', 'Bill_July', 'Bill__June',
#        'Bill_May', 'Bill_April', 'Amount_paid_Sept', 'Amount_paid_Aug',
#        'Amount_paid_July', 'Amount_paid_June', 'Amount_paid_May',
#        'Amount_paid_April'],
#       dtype='object')

# %%
X.head()
# Out:
#    Credit_Amount  Gender  Education  Marital status  Age  Repay_Sept  \
# 0          20000       2          2               1   24           2
# 1         120000       2          2               2   26          -1
# 2          90000       2          2               2   34           0
# 3          50000       2          2               1   37           0
# 4          50000       1          2               1   57          -1
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0          2          -1          -1         -2  ...        689           0
# 1          2           0           0          0  ...       2682        3272
# 2          0           0           0          0  ...      13559       14331
# 3          0           0           0          0  ...      49291       28314
# 4          0          -1           0          0  ...      35835       20940
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0         0           0                 0              689                 0
# 1      3455        3261                 0             1000              1000
# 2     14948       15549              1518             1500              1000
# 3     28959       29547              2000             2019              1200
# 4     19146       19131              2000            36681             10000
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0                 0                0                  0
# 1              1000                0               2000
# 2              1000             1000               5000
# 3              1100             1069               1000
# 4              9000              689                679
#
# [5 rows x 23 columns]

# %%
y.head()
# Out:
#    Y
# 0  1
# 1  1
# 2  0
# 3  0
# 4  0

# %%
y.value_counts()
# Out:
# Y
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
((y.value_counts())/len(y))*100
# Out:
# Y
# 0    77.88
# 1    22.12
# Name: count, dtype: float64

# %%
y.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Y'>

# %% [markdown]
# ## This dataset has imbalanced data for target features.

# %%
len(y)
# Out:
# 30000

# %%
X.head(2)
# Out:
#    Credit_Amount  Gender  Education  Marital status  Age  Repay_Sept  \
# 0          20000       2          2               1   24           2
# 1         120000       2          2               2   26          -1
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0          2          -1          -1         -2  ...        689           0
# 1          2           0           0          0  ...       2682        3272
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0         0           0                 0              689                 0
# 1      3455        3261                 0             1000              1000
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0                 0                0                  0
# 1              1000                0               2000
#
# [2 rows x 23 columns]

# %%
X.dtypes
# Out:
# Credit_Amount        int64
# Gender               int64
# Education            int64
# Marital status       int64
# Age                  int64
# Repay_Sept           int64
# Repay_Aug            int64
# Repay_July           int64
# Repay_June           int64
# Repay_May            int64
# Repay_April          int64
# Bill_Sept            int64
# Bill_Aug             int64
# Bill_July            int64
# Bill__June           int64
# Bill_May             int64
# Bill_April           int64
# Amount_paid_Sept     int64
# Amount_paid_Aug      int64
# Amount_paid_July     int64
# Amount_paid_June     int64
# Amount_paid_May      int64
# Amount_paid_April    int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

num_pipe = make_pipeline(SimpleImputer(strategy='mean'),
                         StandardScaler()
                         ).set_output(transform='pandas')
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    Credit_Amount    Gender  Education  Marital status       Age  Repay_Sept  \
# 0      -1.136720  0.810161   0.185828       -1.057295 -1.246020    1.794564
# 1      -0.365981  0.810161   0.185828        0.858557 -1.029047   -0.874991
# 2      -0.597202  0.810161   0.185828        0.858557 -0.161156    0.014861
# 3      -0.905498  0.810161   0.185828       -1.057295  0.164303    0.014861
# 4      -0.905498 -1.234323   0.185828       -1.057295  2.334029   -0.874991
#
#    Repay_Aug  Repay_July  Repay_June  Repay_May  ...  Bill_July  Bill__June  \
# 0   1.782348   -0.696663   -0.666599  -1.530046  ...  -0.667993   -0.672497
# 1   1.782348    0.138865    0.188746   0.234917  ...  -0.639254   -0.621636
# 2   0.111736    0.138865    0.188746   0.234917  ...  -0.482408   -0.449730
# 3   0.111736    0.138865    0.188746   0.234917  ...   0.032846   -0.232373
# 4   0.111736   -0.696663    0.188746   0.234917  ...  -0.161189   -0.346997
#
#    Bill_May  Bill_April  Amount_paid_Sept  Amount_paid_Aug  Amount_paid_July  \
# 0 -0.663059   -0.652724         -0.341942        -0.227086         -0.296801
# 1 -0.606229   -0.597966         -0.341942        -0.213588         -0.240005
# 2 -0.417188   -0.391630         -0.250292        -0.191887         -0.240005
# 3 -0.186729   -0.156579         -0.221191        -0.169361         -0.228645
# 4 -0.348137   -0.331482         -0.221191         1.335034          0.271165
#
#    Amount_paid_June  Amount_paid_May  Amount_paid_April
# 0         -0.308063        -0.314136          -0.293382
# 1         -0.244230        -0.314136          -0.180878
# 2         -0.244230        -0.248683          -0.012122
# 3         -0.237846        -0.244166          -0.237130
# 4          0.266434        -0.269039          -0.255187
#
# [5 rows x 23 columns]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,y,train_size=0.7,random_state=21)

# %% [markdown]
# ## Balance the Y samples using SMOTE technique

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.12/dist-packages (from imblearn) (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.6.1)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
x_sampl,y_sampl = smote.fit_resample(xtrain,ytrain)

# %%
y_sampl.value_counts()
# Out:
# Y
# 0    16364
# 1    16364
# Name: count, dtype: int64

# %%
xtrain.shape
# Out:
# (21000, 23)

# %%
xtrain.shape[1]
# Out:
# 23

# %% [markdown]
# # Build Neural Network Model

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from keras.models import Sequential
from keras.layers import Input,Dense

# %%
# Initialize the model
model = Sequential()

# Add the Input Layer
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Hidden Layer1
model.add(Dense(units=64,activation='relu'))

# Add the Hidden Layer2
model.add(Dense(units=32,activation='relu'))

# Add the Output Layer
model.add(Dense(units=1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
len(y_sampl)
# Out:
# 32728

# %%
(20*len(y_sampl))/100
# Out:
# 6545.6

# %%
nn = model.fit(x_sampl,y_sampl,validation_split=0.2,epochs=50)
# 20% training data is split  => validation
# 20% of 32728 = used for validation
# Out:
# Epoch 1/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7313 - loss: 0.5681 - val_accuracy: 0.4840 - val_loss: 0.7531
# Epoch 2/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7391 - loss: 0.5415 - val_accuracy: 0.4577 - val_loss: 0.8452
# Epoch 3/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7439 - loss: 0.5341 - val_accuracy: 0.4629 - val_loss: 0.8521
# Epoch 4/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7460 - loss: 0.5293 - val_accuracy: 0.5295 - val_loss: 0.7120
# Epoch 5/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7466 - loss: 0.5258 - val_accuracy: 0.5228 - val_loss: 0.7590
# Epoch 6/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7476 - loss: 0.5226 - val_accuracy: 0.5031 - val_loss: 0.7809
# Epoch 7/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7486 - loss: 0.5188 - val_accuracy: 0.5203 - val_loss: 0.7521
# Epoch 8/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7485 - loss: 0.5170 - val_accuracy: 0.4899 - val_loss: 0.8087
# Epoch 9/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7504 - loss: 0.5135 - val_accuracy: 0.5273 - val_loss: 0.7660
# Epoch 10/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7532 - loss: 0.5108 - val_accuracy: 0.4850 - val_loss: 0.8293
# Epoch 11/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7512 - loss: 0.5096 - val_accuracy: 0.5588 - val_loss: 0.7214
# Epoch 12/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7526 - loss: 0.5065 - val_accuracy: 0.5017 - val_loss: 0.7906
# Epoch 13/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7546 - loss: 0.5039 - val_accuracy: 0.5542 - val_loss: 0.7082
# Epoch 14/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7567 - loss: 0.5015 - val_accuracy: 0.4947 - val_loss: 0.8479
# Epoch 15/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7571 - loss: 0.5002 - val_accuracy: 0.5018 - val_loss: 0.8160
# Epoch 16/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7590 - loss: 0.4969 - val_accuracy: 0.6005 - val_loss: 0.6661
# Epoch 17/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7580 - loss: 0.4948 - val_accuracy: 0.5581 - val_loss: 0.7075
# Epoch 18/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7597 - loss: 0.4924 - val_accuracy: 0.5684 - val_loss: 0.6724
# Epoch 19/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7609 - loss: 0.4907 - val_accuracy: 0.5306 - val_loss: 0.7624
# Epoch 20/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7648 - loss: 0.4882 - val_accuracy: 0.5810 - val_loss: 0.6724
# Epoch 21/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7634 - loss: 0.4876 - val_accuracy: 0.5295 - val_loss: 0.7526
# Epoch 22/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7635 - loss: 0.4851 - val_accuracy: 0.5675 - val_loss: 0.6850
# Epoch 23/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7652 - loss: 0.4819 - val_accuracy: 0.5900 - val_loss: 0.6977
# Epoch 24/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7675 - loss: 0.4809 - val_accuracy: 0.5680 - val_loss: 0.7359
# Epoch 25/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7690 - loss: 0.4782 - val_accuracy: 0.5222 - val_loss: 0.8068
# Epoch 26/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7708 - loss: 0.4751 - val_accuracy: 0.5574 - val_loss: 0.7453
# Epoch 27/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7706 - loss: 0.4745 - val_accuracy: 0.6199 - val_loss: 0.6227
# Epoch 28/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7738 - loss: 0.4715 - val_accuracy: 0.5910 - val_loss: 0.7043
# Epoch 29/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7732 - loss: 0.4695 - val_accuracy: 0.5570 - val_loss: 0.7268
# Epoch 30/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7744 - loss: 0.4699 - val_accuracy: 0.5826 - val_loss: 0.6619
# Epoch 31/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7764 - loss: 0.4663 - val_accuracy: 0.6699 - val_loss: 0.5964
# Epoch 32/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7763 - loss: 0.4654 - val_accuracy: 0.6412 - val_loss: 0.6106
# Epoch 33/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7772 - loss: 0.4628 - val_accuracy: 0.5553 - val_loss: 0.7274
# Epoch 34/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7769 - loss: 0.4609 - val_accuracy: 0.5781 - val_loss: 0.6991
# Epoch 35/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7795 - loss: 0.4596 - val_accuracy: 0.6120 - val_loss: 0.6430
# Epoch 36/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7790 - loss: 0.4581 - val_accuracy: 0.5391 - val_loss: 0.7834
# Epoch 37/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7795 - loss: 0.4577 - val_accuracy: 0.6114 - val_loss: 0.6609
# Epoch 38/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7791 - loss: 0.4564 - val_accuracy: 0.5533 - val_loss: 0.7490
# Epoch 39/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7836 - loss: 0.4535 - val_accuracy: 0.6124 - val_loss: 0.6468
# Epoch 40/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7836 - loss: 0.4517 - val_accuracy: 0.5836 - val_loss: 0.6982
# Epoch 41/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7839 - loss: 0.4500 - val_accuracy: 0.6245 - val_loss: 0.6274
# Epoch 42/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7843 - loss: 0.4488 - val_accuracy: 0.6673 - val_loss: 0.5834
# Epoch 43/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7837 - loss: 0.4498 - val_accuracy: 0.6273 - val_loss: 0.6445
# Epoch 44/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7838 - loss: 0.4475 - val_accuracy: 0.6245 - val_loss: 0.6250
# Epoch 45/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7878 - loss: 0.4468 - val_accuracy: 0.6752 - val_loss: 0.5763
# Epoch 46/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7867 - loss: 0.4449 - val_accuracy: 0.5947 - val_loss: 0.7047
# Epoch 47/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7885 - loss: 0.4437 - val_accuracy: 0.5868 - val_loss: 0.7030
# Epoch 48/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7859 - loss: 0.4425 - val_accuracy: 0.6416 - val_loss: 0.6159
# Epoch 49/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7902 - loss: 0.4408 - val_accuracy: 0.6080 - val_loss: 0.6837
# Epoch 50/50
# 819/819 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7904 - loss: 0.4406 - val_accuracy: 0.6089 - val_loss: 0.6734

# %% [markdown]
# # Learning Curve

# %%
import matplotlib.pyplot as plt
plt.plot(nn.history['loss'],label='Training Loss')
plt.plot(nn.history['val_loss'],label='Validation Loss')
plt.xlabel('Number of Epochs')
plt.ylabel("Binary Cross Entropy")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %%
model.evaluate(xtest,ytest)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7791 - loss: 0.5282
# [0.5282493233680725, 0.7791110873222351]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ypreds = model.predict(xtest)
ypreds[:10]
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# array([[5.61853170e-01],
#        [6.27326965e-01],
#        [1.08426124e-01],
#        [2.20731963e-04],
#        [4.60677773e-01],
#        [2.93669313e-01],
#        [5.54195404e-01],
#        [1.20710686e-01],
#        [3.70067865e-01],
#        [4.12544161e-02]], dtype=float32)

# %%
ytest.head()
# Out:
#        Y
# 6677   0
# 20672  1
# 19682  0
# 23589  0
# 16352  1

# %%
ypreds_new = []
for i in ypreds:
  if i>0.5:
    ypreds_new.append(1)
  else:
    ypreds_new.append(0)
ypreds_new[:10]
# Out:
# [1, 1, 0, 0, 0, 0, 1, 0, 0, 0]

# %%
ytest.value_counts()
# Out:
# Y
# 0    7000
# 1    2000
# Name: count, dtype: int64

# %%
ConfusionMatrixDisplay.from_predictions(ytest,ypreds_new)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest,ypreds_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      7000
#            1       0.50      0.49      0.50      2000
#
#     accuracy                           0.78      9000
#    macro avg       0.68      0.68      0.68      9000
# weighted avg       0.78      0.78      0.78      9000
